# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### I. Numerical Computing with NumPy.
# #### 1. Array Creation & Basic Operations

# %%
#A. Task: Create a 1D array of 10 random integers. Create a 3x3 identity matrix.
arr = np.random.randint(10, 100, 10)
print(arr)
identity_matrix = np.identity(3)
print(identity_matrix)
# Out:
# [58 91 86 17 43 76 16 82 87 40]
# [[1. 0. 0.]
#  [0. 1. 0.]
#  [0. 0. 1.]]

# %%
#B. Task: Multiply the 1D array by a scalar value without using any for loops.
print(arr*10)
# Out:
# [580 910 860 170 430 760 160 820 870 400]

# %%
#C. Task: Create two 3x3 matrices. Perform both element-wise multiplication and the dot product.
matrix_1 = np.array([[1, 2, 3],
            [3, 2, 1],
            [7, 6, 9]])

matrix_2 = np.array([[2, 2, 2],
            [3, 3, 3],
            [10, 10, 10]])

print(matrix_1*matrix_2)
print(np.dot(matrix_1, matrix_2))
# Out:
# [[ 2  4  6]
#  [ 9  6  3]
#  [70 60 90]]
# [[ 38  38  38]
#  [ 22  22  22]
#  [122 122 122]]

# %% [markdown]
# #### 2. Statistical Methods

# %%
#A. Task: Generate an array of 100 random numbers from a normal distribution.
arr = np.random.randn(100)
arr
# Out:
# array([ 0.42987226, -1.19982155, -1.14886447, -0.72021364, -0.25607188,
#        -1.20096275,  0.10934296,  0.68002912,  0.220421  , -0.30919442,
#        -0.12047959,  1.01483865, -1.08667493,  0.02088823, -0.44481821,
#         1.06136198, -0.9936661 , -0.59206534, -0.01251348,  1.0789999 ,
#        -0.74428522,  1.3198607 , -0.24071488, -0.92178752, -1.05538094,
#        -0.38199527, -2.02263204,  1.28939804, -0.05480739,  0.23987708,
#         1.05138875, -1.51544906,  2.32911382,  0.2297793 , -0.23508235,
#         0.3459381 ,  0.46668315, -0.58287173,  0.95620628, -0.40527528,
#         2.23946305, -1.44610137, -0.75442985, -0.16079818, -1.05102963,
#         0.53908749,  0.93934788, -1.61547734,  0.34471342, -2.32977538,
#         0.8549432 ,  1.42353894,  0.61549448,  0.02987604, -0.47125304,
#         0.72551892, -0.34667296, -1.7843781 , -0.37076971, -0.63908932,
#        -0.47452076,  0.84453964, -2.2601532 ,  0.35561805, -0.85999856,
# ...

# %%
# B. Task: Calculate and print the mean, median, standard deviation, and variance of the array. Find the index of the maximum value.
mean = np.mean(arr)
median = np.median(arr)
standard_deviation = np.std(arr)
variance = np.var(arr)
max_index = np.argmax(arr)
print(f"Mean: {mean}")
print(f"Median: {median}")
print(f"Standard Deviation: {standard_deviation}")
print(f"Variance: {variance}")
print(f"Max Index: {max_index}")
# Out:
# Mean: 0.04148117654576785
# Median: 0.14777690005698613
# Standard Deviation: 1.0582454351725081
# Variance: 1.1198834010634513
# Max Index: 47

# %% [markdown]
# ### II. Tabular Data with Pandas
# #### 1. Series

# %%
#A. Task: Create a Series object
series = pd.Series([0, -1, 4, -3, 2])
print(series)
# Out:
# 0    0
# 1   -1
# 2    4
# 3   -3
# 4    2
# dtype: int64

# %%
#B. Task: Modify data in the Series (only single value, and all values)
series[1] *= -1
print(series)

series += 10
print(series)
# Out:
# 0    0
# 1    1
# 2    4
# 3   -3
# 4    2
# dtype: int64
# 0    10
# 1    11
# 2    14
# 3     7
# 4    12
# dtype: int64

# %%
#C. Task: Modify index of the Series
series.index = [f"Index: {-i}" for i in range(len(series))]
print(series)
# Out:
# Index: 0     10
# Index: -1    11
# Index: -2    14
# Index: -3     7
# Index: -4    12
# dtype: int64

# %% [markdown]
# #### 2. DataFrames

# %%
#A. Task: Create a Pandas DataFrame from a Python dictionary.
dict = {
    "A": np.random.randint(1, 100, 10), 
    "T": np.random.randint(1, 100, 10), 
    "C": np.random.randint(1, 100, 10), 
    "G": np.random.randint(1, 100, 10)
    }

dataframe = pd.DataFrame(dict, index=[f"Sequence: {i+1}" for i in range(10)])
dataframe
# Out:
#                A   T   C   G
# Sequence: 1   47   8  12  26
# Sequence: 2   86  89  89  90
# Sequence: 3   54  90  29  69
# Sequence: 4   80  53  93  88
# Sequence: 5    3  53  37  67
# Sequence: 6   83  55  35  13
# Sequence: 7    9   6  34  25
# Sequence: 8   31  60  48  21
# Sequence: 9   20  88  37  30
# Sequence: 10  54  74  68  29

# %%
#B. Task: Construct a DataFrame from a 2D NumPy array, manually assigning column names (e.g., 'Feature_1', 'Feature_2', 'Target').
array_2d = np.random.randn(3, 4)
df = pd.DataFrame(array_2d, columns = ["Numbers A", "Numbers B", "Numbers C", "Numbers D"])
df
# Out:
#    Numbers A  Numbers B  Numbers C  Numbers D
# 0  -1.218640   0.734350  -1.270573  -0.229237
# 1   1.535575   0.820152  -0.588746   0.366202
# 2   1.436913  -1.526313   1.175046  -0.004185

# %%
# C. Task: Create own column as sum (or any other result) of using other columns
dataframe["Total length"] = [dataframe.values[i].sum() for i in range(10)]
dataframe
# Out:
#                A   T   C   G  Total length
# Sequence: 1   47   8  12  26            93
# Sequence: 2   86  89  89  90           354
# Sequence: 3   54  90  29  69           242
# Sequence: 4   80  53  93  88           314
# Sequence: 5    3  53  37  67           160
# Sequence: 6   83  55  35  13           186
# Sequence: 7    9   6  34  25            74
# Sequence: 8   31  60  48  21           160
# Sequence: 9   20  88  37  30           175
# Sequence: 10  54  74  68  29           225

# %% [markdown]
# #### 3. Data Selection and Indexing

# %%
#A. Task: Use .loc to select rows based on a specific index label.
dataframe.loc["Sequence: 4"]
# Out:
# A                80
# T                53
# C                93
# G                88
# Total length    314
# Name: Sequence: 4, dtype: int64

# %%
#B. Task: Use .iloc to select the first 5 rows and the last 2 columns of the DataFrame.
dataframe.iloc[:5, 3:]
# Out:
#               G  Total length
# Sequence: 1  26            93
# Sequence: 2  90           354
# Sequence: 3  69           242
# Sequence: 4  88           314
# Sequence: 5  67           160

# %%
#C. Task: Filter the DataFrame to show only rows where 'Feature_1' is greater than a specific threshold.
dataframe[(dataframe["A"]>50) & (dataframe["G"]<60)]
# Out:
#                A   T   C   G  Total length
# Sequence: 6   83  55  35  13           186
# Sequence: 10  54  74  68  29           225

# %% [markdown]
# ### III. Independent Practical Task: loading data from a table

# %%
df = pd.read_csv("C:/Users/rodio/PycharmProjects/DataMining/src/boston.csv")
df.head(10)
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM    AGE     DIS  RAD    TAX  \
# 0  0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821    5  311.0
# 1  0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821    5  311.0
# 2  0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821    5  311.0
# 3  0.03237   NaN   2.18   0.0  0.458  6.998    NaN  6.0622    3    NaN
# 4      NaN   0.0   2.18   NaN    NaN    NaN   54.2  6.0622    3  222.0
# 5  0.02985   0.0   2.18   0.0  0.458  6.430   58.7  6.0622    3    NaN
# 6  0.08829  12.5   7.87   0.0  0.524  6.012   66.6  5.5605    5  311.0
# 7  0.14455  12.5   7.87   0.0  0.524  6.172   96.1  5.9505    5  311.0
# 8  0.21124  12.5   7.87   0.0  0.524  5.631  100.0  6.0821    5  311.0
# 9  0.17004  12.5   7.87   0.0  0.524  6.004   85.9  6.5921    5  311.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.2  386.63  29.93  16.5
# 1     15.2  386.63  29.93  16.5
# 2     15.2  386.63  29.93  16.5
# 3     18.7     NaN   2.94   NaN
# ...

# %%
print(df.dtypes)
# Out:
# CRIM       float64
# ZN         float64
# INDUS      float64
# CHAS       float64
# NOX        float64
# RM         float64
# AGE        float64
# DIS        float64
# RAD          int64
# TAX        float64
# PTRATIO    float64
# B          float64
# LSTAT      float64
# MEDV       float64
# dtype: object

# %%
# Statistics on missing values
missing_counts = df.isna().sum()
print(missing_counts)
# Out:
# CRIM       1
# ZN         1
# INDUS      0
# CHAS       1
# NOX        1
# RM         1
# AGE        1
# DIS        0
# RAD        0
# TAX        2
# PTRATIO    1
# B          1
# LSTAT      1
# MEDV       1
# dtype: int64

# %%
# Statistics on duplicates
total_duplicates = df.duplicated().sum()
print(total_duplicates)
# Out:
# 6

# %%
# General statistics
stats = df.describe()
print(stats)
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  505.000000  505.000000  506.000000  505.000000  505.000000  505.000000
# mean     3.616803   11.499010   11.149328    0.069307    0.554993    6.274008
# std      8.609841   23.310693    6.849668    0.254227    0.115825    0.704245
# min      0.009060    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.083080    0.000000    5.190000    0.000000    0.449000    5.876000
# 50%      0.251990    0.000000    9.690000    0.000000    0.538000    6.193000
# 75%      3.678220   12.500000   18.100000    0.000000    0.624000    6.618000
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  505.000000  506.000000  506.000000  504.000000  505.000000  505.000000
# mean    68.866139    3.813980    9.575099  409.303571   18.410099  356.724198
# ...

# %%
#NumPy Integration
tax_array = df['TAX'].to_numpy()
avg_tax = np.nanmean(tax_array)
print(avg_tax)
# Out:
# 409.30357142857144

# %% [markdown]
# #### Tax data visualisation with average tax red line

# %%
plot = df['TAX'].plot(title='Average Tax')
plot.axhline(avg_tax, color='r')

# %% [markdown]
# #### Overall data visualisation

# %%
df.plot()
# Out:
# <Axes: >
